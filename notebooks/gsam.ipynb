# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import numpy as np

DATA_PATH = '../data/'

from lumivid.gsam.gsam import get_segmentation_mask, show_segmentation_mask, show_bounding_boxes
from lumivid.utils.video_utils import get_video, get_video_frame_iterator, get_frame_from_video

# %%
video_path = DATA_PATH + f"preprocessing/processed_scenes/P3Scene15.mp4"
video = get_video(video_path)
bgr_frame, _ = get_frame_from_video(video, 0, split=False, masked=True, reframed=True)
rgb_frame = bgr_frame[..., ::-1]

plt.figure(figsize=(15, 15))
plt.imshow(rgb_frame)
plt.show()

# %%
segmentation_mask, detections, class_dict = get_segmentation_mask(bgr_frame, size_factor=1)
# Out:
# final text_encoder_type: bert-base-uncased

# %%
show_bounding_boxes(rgb_frame, detections)

# %%
show_segmentation_mask(bgr_frame, segmentation_mask, class_dict, size_factor=1)
